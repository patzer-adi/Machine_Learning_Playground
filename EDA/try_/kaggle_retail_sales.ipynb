# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = 'Retail and wherehouse Sale.csv'
df = pd.read_csv(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              30000 non-null  int64
#  1   MONTH             30000 non-null  int64
#  2   SUPPLIER          29967 non-null  object
#  3   ITEM CODE         30000 non-null  object
#  4   ITEM DESCRIPTION  30000 non-null  object
#  5   ITEM TYPE         30000 non-null  object
#  6   RETAIL SALES      29999 non-null  float64
#  7   RETAIL TRANSFERS  30000 non-null  float64
#  8   WAREHOUSE SALES   30000 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 2.1+ MB

# %%
df.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %%
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'SUPPLIER', 'ITEM CODE', 'ITEM DESCRIPTION',
#        'ITEM TYPE', 'RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# YEAR                 0
# MONTH                0
# SUPPLIER            33
# ITEM CODE            0
# ITEM DESCRIPTION     0
# ITEM TYPE            0
# RETAIL SALES         1
# RETAIL TRANSFERS     0
# WAREHOUSE SALES      0
# dtype: int64

# %%
df.duplicated().values.any()
# Out:
# False

# %%
df['MONTH'].unique()
# Out:
# array([1, 7, 3, 9])

# %%
df['MONTH'].value_counts()
# Out:
# MONTH
# 1    11987
# 7    11190
# 3     5730
# 9     1093
# Name: count, dtype: int64

# %%
df['SUPPLIER'].unique()
# Out:
# array(['REPUBLIC NATIONAL DISTRIBUTING CO', 'PWSWN INC',
#        'RELIABLE CHURCHILL LLLP', 'LANTERNA DISTRIBUTORS INC',
#        'DIONYSOS IMPORTS INC', 'KYSELA PERE ET FILS LTD',
#        'SANTA MARGHERITA USA INC', 'BROWN-FORMAN BEVERAGES WORLDWIDE',
#        'JIM BEAM BRANDS CO', 'INTERNATIONAL CELLARS LLC',
#        'HEAVEN HILL DISTILLERIES INC', 'BACCHUS IMPORTERS LTD',
#        'MONSIEUR TOUTON SELECTION',
#        'THE COUNTRY VINTNER, LLC DBA WINEBOW', 'ROYAL WINE CORP',
#        'STE MICHELLE WINE ESTATES', 'Default', 'SAZERAC CO',
#        'SALVETO IMPORTS LLC', 'HUB WINE CORPORATION',
#        'ALLAGASH BREWING COMPANY', 'CAMPARI AMERICA LLC',
#        'PERNOD RICARD USA LLC', 'PRESTIGE BEVERAGE GROUP OF MD LLC',
#        'BACARDI USA INC', 'YOUNG WON TRADING INC',
#        'TROEGS BREWING COMPANY', 'CASTLE BRANDS USA CORP', 'LEGENDS LTD',
#        'WASHBURN WINE CO', 'CELICAR LLC DBA TWIN VALLEY DISTILLERS',
#        'DOPS INC', 'JACKSON FAMILY ENTERPRISES INC',
# ...

# %%
df['ITEM DESCRIPTION'].unique()
# Out:
# array(['BOOTLEG RED - 750ML', 'MOMENT DE PLAISIR - 750ML',
#        'S SMITH ORGANIC PEAR CIDER - 18.7OZ', ...,
#        'ANXO NEVERTHELESS WE PERSISTED 1/6 KEG',
#        "E' ARTE PRIMITIVO - 750ML",
#        'CINCO SENTIDOS PAPALOMETL MEZCAL - 750ML'], dtype=object)

# %%
df['ITEM TYPE'].unique()
# Out:
# array(['WINE', 'BEER', 'LIQUOR', 'STR_SUPPLIES', 'KEGS', 'REF', 'DUNNAGE',
#        'NON-ALCOHOL'], dtype=object)

# %%
sales_items = df[df['ITEM TYPE'].isin(['STR_SUPPLIES', 'KEGS', 'REF', 'DUNNAGE'])][['ITEM TYPE', 'ITEM DESCRIPTION']]

# %%
sales_items.head()
# Out:
#        ITEM TYPE              ITEM DESCRIPTION
# 24  STR_SUPPLIES          TWO BOTTLE WINE TOTE
# 46          KEGS  FIRESTONE NITRO MERLIN - 50L
# 48  STR_SUPPLIES         FOUR BOTTLE WINE TOTE
# 77  STR_SUPPLIES  WINE GIFT TOTE SINGLE BOTTLE
# 83          KEGS     ALHAMBRA RESERVA 20L-1/6K

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, SUPPLIER, ITEM CODE, ITEM DESCRIPTION, ITEM TYPE, RETAIL SALES, RETAIL TRANSFERS, WAREHOUSE SALES]
# Index: []

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().any()
# Out:
# YEAR                False
# MONTH               False
# SUPPLIER             True
# ITEM CODE           False
# ITEM DESCRIPTION    False
# ITEM TYPE           False
# RETAIL SALES         True
# RETAIL TRANSFERS    False
# WAREHOUSE SALES     False
# dtype: bool

# %%
df_cleaned = df.dropna(subset=['RETAIL SALES'])

# %%
print(df_cleaned)
# Out:
#        YEAR  MONTH                              SUPPLIER ITEM CODE  \
# 0      2020      1     REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                             PWSWN INC    100024
# 2      2020      1               RELIABLE CHURCHILL LLLP      1001
# 3      2020      1             LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1                  DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                   ...       ...
# 29995  2020      3  THE COUNTRY VINTNER, LLC DBA WINEBOW    352322
# 29996  2020      3                       OSLO ENTERPRISE    352324
# 29997  2020      3       OPICI FAMILY DISTRIBUTING OF MD    352354
# 29998  2020      3                   CAMPARI AMERICA LLC     35238
# 29999  2020      3  THE COUNTRY VINTNER, LLC DBA WINEBOW    352380
#
#                             ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                        BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df_cleaned = df.dropna(subset=['SUPPLIER'])
print(df_cleaned)
# Out:
#        YEAR  MONTH                              SUPPLIER ITEM CODE  \
# 0      2020      1     REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                             PWSWN INC    100024
# 2      2020      1               RELIABLE CHURCHILL LLLP      1001
# 3      2020      1             LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1                  DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                   ...       ...
# 29995  2020      3  THE COUNTRY VINTNER, LLC DBA WINEBOW    352322
# 29996  2020      3                       OSLO ENTERPRISE    352324
# 29997  2020      3       OPICI FAMILY DISTRIBUTING OF MD    352354
# 29998  2020      3                   CAMPARI AMERICA LLC     35238
# 29999  2020      3  THE COUNTRY VINTNER, LLC DBA WINEBOW    352380
#
#                             ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                        BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df_cleaned = df.dropna(how='all')
print(df_cleaned)
# Out:
#        YEAR  MONTH                              SUPPLIER ITEM CODE  \
# 0      2020      1     REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                             PWSWN INC    100024
# 2      2020      1               RELIABLE CHURCHILL LLLP      1001
# 3      2020      1             LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1                  DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                   ...       ...
# 29995  2020      3  THE COUNTRY VINTNER, LLC DBA WINEBOW    352322
# 29996  2020      3                       OSLO ENTERPRISE    352324
# 29997  2020      3       OPICI FAMILY DISTRIBUTING OF MD    352354
# 29998  2020      3                   CAMPARI AMERICA LLC     35238
# 29999  2020      3  THE COUNTRY VINTNER, LLC DBA WINEBOW    352380
#
#                             ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                        BOOTLEG RED - 750ML      WINE          0.00
# ...
